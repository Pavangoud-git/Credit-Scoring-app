# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavangoud-git/Credit-Scoring-app/blob/main/app_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install streamlit

# %%
import streamlit as st
import pandas as pd
import joblib

# Load model
model = joblib.load("random_forest_model.pkl")

st.title("Credit Scoring Model")

age = st.number_input("Age", min_value=18, max_value=100)
income = st.number_input("Annual Income")
debt = st.number_input("Existing Debt")

if st.button("Predict"):

    # Create sample input
    sample = pd.DataFrame({
        "Age": [age],
        "Annual_Income_INR": [income],
        "Existing_Debt": [debt]
    })

    prediction = model.predict(sample)

    if prediction[0] == 1:
        st.success("Good Credit Risk")
    else:
        st.error("Bad Credit Risk")
# Out:
# 2026-06-19 04:15:52.417 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 04:15:52.832
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-06-19 04:15:52.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 04:15:52.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 04:15:52.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 04:15:52.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-19 04:15:52.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
